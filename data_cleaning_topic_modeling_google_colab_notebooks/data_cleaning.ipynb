# %% [markdown]
# # Job Postings Data Cleaning

# %% [markdown]
# ## Import Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/team-25/

# !pip install langdetect -q

import pandas as pd
import numpy as np
from langdetect import detect
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

# %%
[csv_file for csv_file in os.listdir("./data") if csv_file.endswith(".csv")]

# %% [markdown]
# ## Import Raw Data

# %%
filelist = ['DataAnalyst.csv', 'DataScientist.csv', 'DataEngineer.csv']
df_list=[]
for filename in filelist:
  df = pd.read_csv(f"./data/{filename}")
  df["job_family"] = filename.replace(".csv","")
  df_list.append(df)

df = pd.concat(df_list)
df.drop(columns=df.columns[0], inplace=True)
df
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2523                                     Cloud Engineer
# 2524                                Electrical Engineer
# 2525                              Sr. Big Data Engineer
# 2526                     Senior Big Data / ETL Engineer
# 2527                                     Cloud Engineer
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2523  $76K-$128K (Glassdoor est.)
# 2524  $76K-$128K (Glassdoor est.)
# 2525  $76K-$128K (Glassdoor est.)
# 2526  $76K-$128K (Glassdoor est.)
# 2527  $76K-$128K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2523  The Expertise You Have Proven expertise in dev...     4.5
# 2524  Lockheed Martin is seeking a Circuit and FPGA ...     2.9
# 2525  Posting Title Principal Data Engineer (Contrac...     3.7
# 2526  Your Opportunity\n\nCharles Schwab & Co., Inc ...     3.5
# 2527  Cloud Engineer Westlake, TX 6+ months Descript...     3.6
#
#                                    Company Name        Location  \
# 0                Vera Institute of Justice\n3.2    New York, NY
# 1       Visiting Nurse Service of New York\n3.8    New York, NY
# 2                              Squarespace\n3.4    New York, NY
# 3                                 Celerity\n4.1    New York, NY
# 4                                  FanDuel\n3.9    New York, NY
# ...                                         ...             ...
# 2523                            PMG Global\n4.5    Westlake, TX
# 2524            Albin Engineering Services\n2.9  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions\n3.7      Irving, TX
# 2526                                Schwab\n3.5    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.\n3.6    Westlake, TX
#
#              Headquarters                    Size  Founded  \
# 0            New York, NY    201 to 500 employees     1961
# 1            New York, NY        10000+ employees     1893
# 2            New York, NY  1001 to 5000 employees     2003
# 3              McLean, VA    201 to 500 employees     2002
# 4            New York, NY   501 to 1000 employees     2009
# ...                   ...                     ...      ...
# 2523          Herndon, VA       1 to 50 employees       -1
# 2524      Santa Clara, CA     51 to 200 employees     1993
# 2525       Cincinnati, OH   501 to 1000 employees       -1
# 2526  Dettenheim, Germany                 Unknown       -1
# 2527          Raleigh, NC   501 to 1000 employees     2000
#
#                    Type of ownership                          Industry  \
# 0             Nonprofit Organization                 Social Assistance
# 1             Nonprofit Organization  Health Care Services & Hospitals
# 2                  Company - Private                          Internet
# 3     Subsidiary or Business Segment                       IT Services
# 4                  Company - Private               Sports & Recreation
# ...                              ...                               ...
# 2523               Company - Private      Computer Hardware & Software
# 2524               Company - Private            Staffing & Outsourcing
# 2525               Company - Private                       IT Services
# 2526                Company - Public                                -1
# 2527               Company - Private            Staffing & Outsourcing
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2523            Information Technology      $1 to $5 million (USD)
# 2524                 Business Services     $5 to $10 million (USD)
# 2525            Information Technology  $100 to $500 million (USD)
# 2526                                -1    Unknown / Non-Applicable
# 2527                 Business Services    $25 to $50 million (USD)
#
#      Competitors Easy Apply    job_family  index
# 0             -1       True   DataAnalyst    NaN
# 1             -1         -1   DataAnalyst    NaN
# 2        GoDaddy         -1   DataAnalyst    NaN
# 3             -1         -1   DataAnalyst    NaN
# 4     DraftKings       True   DataAnalyst    NaN
# ...          ...        ...           ...    ...
# 2523          -1         -1  DataEngineer    NaN
# 2524          -1         -1  DataEngineer    NaN
# 2525          -1         -1  DataEngineer    NaN
# 2526          -1         -1  DataEngineer    NaN
# 2527          -1         -1  DataEngineer    NaN
#
# [8690 rows x 17 columns]

# %% [markdown]
# ## Basic Data Cleaning

# %%
df.drop(columns=["Competitors", "Easy Apply", "Headquarters","index"], inplace= True)

# converts salary estimate from looking like "$10K - $20K (Glassdoor Est....)" to 10,000 in lower bound column and 20,000 in upper bound column
df["Salary_Estimate_Lower_Bound"] = df["Salary Estimate"].apply(lambda x: x.split("-")[0] if x != "-1" else "$0")
df["Salary_Estimate_Upper_Bound"] = df["Salary Estimate"].apply(lambda x: x.split("-")[1].split(" (")[0] if x != "-1" else "$0" )
# converts salary estimate from looking like "$10K - $20K (Glassdoor Est....)" to 10,000 in lower bound column and 20,000 in upper bound column
df["Salary_Estimate_Lower_Bound"] = df["Salary Estimate"].apply(lambda x: x.split("-")[0] if x != "-1" else "$0")+"H"
df["Salary_Estimate_Upper_Bound"] = df["Salary Estimate"].apply(lambda x: x.split("-")[1].split(" ")[0].split("(")[0] if x != "-1" else "$0" )+"H"
df["Salary_Estimate_Lower_Bound"] = df["Salary_Estimate_Lower_Bound"].str.strip("$").replace({"KH":"*1e3", "MH":"*1e6", "H": "*2080"}, regex=True).map(pd.eval).astype(int)
df["Salary_Estimate_Upper_Bound"] = df["Salary_Estimate_Upper_Bound"].str.strip("$").replace({"KH":"*1e3", "MH":"*1e6", "H": "*2080"}, regex=True).map(pd.eval).astype(int)
df.drop(index = df.loc[ df["Salary Estimate"] =="-1"].index, inplace=True) # only 1 row
df.drop(columns = ["Salary Estimate"] , inplace=True) # already have this

# cleaning company data
df.drop(index = df [ ((df["Company Name"]=="-1") | (df["Company Name"].isna()))].index, inplace=True) # only 1 row
df["Company Name"] = df["Company Name"].apply(lambda x : x.split("\n")[0]) # necessary because rating seems to get attached to end of company name

# # get rid of non-english postings
df["language_code"] = df["Job Description"].apply(lambda x: detect(x[:200]))
df.drop(index = df[df["language_code"]!= "en"].index, inplace=True) # only 3 entries

# addition cleaning putting -1 to unknown or n/a
df.loc[ df.Size == "-1", "Size"] = "Unknown"
df.loc[ df["Type of ownership"] == "-1", "Type of ownership"] = "Unknown"
df.loc[ df["Revenue"] == "-1", "Revenue"] = "Unknown / Non-Applicable"
df.loc[ df["Industry"] == "-1", "Industry"] = "Unknown"
df.loc[ df["Sector"] == "-1", "Sector"] = "Unknown"

# %%
df
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2523                                     Cloud Engineer
# 2524                                Electrical Engineer
# 2525                              Sr. Big Data Engineer
# 2526                     Senior Big Data / ETL Engineer
# 2527                                     Cloud Engineer
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2523  The Expertise You Have Proven expertise in dev...     4.5
# 2524  Lockheed Martin is seeking a Circuit and FPGA ...     2.9
# 2525  Posting Title Principal Data Engineer (Contrac...     3.7
# 2526  Your Opportunity\n\nCharles Schwab & Co., Inc ...     3.5
# 2527  Cloud Engineer Westlake, TX 6+ months Descript...     3.6
#
#                               Company Name        Location  \
# 0                Vera Institute of Justice    New York, NY
# 1       Visiting Nurse Service of New York    New York, NY
# 2                              Squarespace    New York, NY
# 3                                 Celerity    New York, NY
# 4                                  FanDuel    New York, NY
# ...                                    ...             ...
# 2523                            PMG Global    Westlake, TX
# 2524            Albin Engineering Services  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions      Irving, TX
# 2526                                Schwab    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.    Westlake, TX
#
#                         Size  Founded               Type of ownership  \
# 0       201 to 500 employees     1961          Nonprofit Organization
# 1           10000+ employees     1893          Nonprofit Organization
# 2     1001 to 5000 employees     2003               Company - Private
# 3       201 to 500 employees     2002  Subsidiary or Business Segment
# 4      501 to 1000 employees     2009               Company - Private
# ...                      ...      ...                             ...
# 2523       1 to 50 employees       -1               Company - Private
# 2524     51 to 200 employees     1993               Company - Private
# 2525   501 to 1000 employees       -1               Company - Private
# 2526                 Unknown       -1                Company - Public
# 2527   501 to 1000 employees     2000               Company - Private
#
#                               Industry                            Sector  \
# 0                    Social Assistance                        Non-Profit
# 1     Health Care Services & Hospitals                       Health Care
# 2                             Internet            Information Technology
# 3                          IT Services            Information Technology
# 4                  Sports & Recreation  Arts, Entertainment & Recreation
# ...                                ...                               ...
# 2523      Computer Hardware & Software            Information Technology
# 2524            Staffing & Outsourcing                 Business Services
# 2525                       IT Services            Information Technology
# 2526                           Unknown                           Unknown
# 2527            Staffing & Outsourcing                 Business Services
#
#                          Revenue    job_family  Salary_Estimate_Lower_Bound  \
# 0     $100 to $500 million (USD)   DataAnalyst                        37000
# 1         $2 to $5 billion (USD)   DataAnalyst                        37000
# 2       Unknown / Non-Applicable   DataAnalyst                        37000
# 3      $50 to $100 million (USD)   DataAnalyst                        37000
# 4     $100 to $500 million (USD)   DataAnalyst                        37000
# ...                          ...           ...                          ...
# 2523      $1 to $5 million (USD)  DataEngineer                        76000
# 2524     $5 to $10 million (USD)  DataEngineer                        76000
# 2525  $100 to $500 million (USD)  DataEngineer                        76000
# 2526    Unknown / Non-Applicable  DataEngineer                        76000
# 2527    $25 to $50 million (USD)  DataEngineer                        76000
#
#       Salary_Estimate_Upper_Bound language_code
# 0                           66000            en
# 1                           66000            en
# 2                           66000            en
# 3                           66000            en
# 4                           66000            en
# ...                           ...           ...
# 2523                       128000            en
# 2524                       128000            en
# 2525                       128000            en
# 2526                       128000            en
# 2527                       128000            en
#
# [8656 rows x 15 columns]

# %% [markdown]
# ## Text Data Cleaning

# %%
def clean_text(text_string,lemmatize=False):
  # TODO: Rewrite function to decrease run-time.
  text_data = re.sub('[^a-zA-Z]', ' ', text_string)
  text_data = text_data.lower()
  text_data = text_data.split()
  clean_text = ' '.join(text_data)
  if lemmatize:
    wl = WordNetLemmatizer()
    text_data = [wl.lemmatize(word) for word in text_data if not word in set(stopwords.words('english'))]
    text_data = ' '.join(text_data)
    return text_data
  else:
    return clean_text

df["clean_job_description"] = df["Job Description"].apply(lambda x: clean_text(x))
df["lemmatized_job_description"] = df["Job Description"].apply(lambda x: clean_text(x, lemmatize=True))
df.drop(columns = ["language_code"], inplace=True)
df["clean_job_title"] = df["Job Title"].apply(lambda x: clean_text(x))
job_family_map = {"DataEngineer": "data engineer", "DataAnalyst": "data analyst", "DataScientist": "data scientist"}
df["job_family"] = df["job_family"].apply(lambda x: job_family_map[x])

# %%
df
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2523                                     Cloud Engineer
# 2524                                Electrical Engineer
# 2525                              Sr. Big Data Engineer
# 2526                     Senior Big Data / ETL Engineer
# 2527                                     Cloud Engineer
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2523  The Expertise You Have Proven expertise in dev...     4.5
# 2524  Lockheed Martin is seeking a Circuit and FPGA ...     2.9
# 2525  Posting Title Principal Data Engineer (Contrac...     3.7
# 2526  Your Opportunity\n\nCharles Schwab & Co., Inc ...     3.5
# 2527  Cloud Engineer Westlake, TX 6+ months Descript...     3.6
#
#                               Company Name        Location  \
# 0                Vera Institute of Justice    New York, NY
# 1       Visiting Nurse Service of New York    New York, NY
# 2                              Squarespace    New York, NY
# 3                                 Celerity    New York, NY
# 4                                  FanDuel    New York, NY
# ...                                    ...             ...
# 2523                            PMG Global    Westlake, TX
# 2524            Albin Engineering Services  Fort Worth, TX
# 2525  Cincinnati Bell Technology Solutions      Irving, TX
# 2526                                Schwab    Westlake, TX
# 2527        SPECTRAFORCE TECHNOLOGIES Inc.    Westlake, TX
#
#                         Size  Founded               Type of ownership  \
# 0       201 to 500 employees     1961          Nonprofit Organization
# 1           10000+ employees     1893          Nonprofit Organization
# 2     1001 to 5000 employees     2003               Company - Private
# 3       201 to 500 employees     2002  Subsidiary or Business Segment
# 4      501 to 1000 employees     2009               Company - Private
# ...                      ...      ...                             ...
# 2523       1 to 50 employees       -1               Company - Private
# 2524     51 to 200 employees     1993               Company - Private
# 2525   501 to 1000 employees       -1               Company - Private
# 2526                 Unknown       -1                Company - Public
# 2527   501 to 1000 employees     2000               Company - Private
#
#                               Industry                            Sector  \
# 0                    Social Assistance                        Non-Profit
# 1     Health Care Services & Hospitals                       Health Care
# 2                             Internet            Information Technology
# 3                          IT Services            Information Technology
# 4                  Sports & Recreation  Arts, Entertainment & Recreation
# ...                                ...                               ...
# 2523      Computer Hardware & Software            Information Technology
# 2524            Staffing & Outsourcing                 Business Services
# 2525                       IT Services            Information Technology
# 2526                           Unknown                           Unknown
# 2527            Staffing & Outsourcing                 Business Services
#
#                          Revenue     job_family  Salary_Estimate_Lower_Bound  \
# 0     $100 to $500 million (USD)   data analyst                        37000
# 1         $2 to $5 billion (USD)   data analyst                        37000
# 2       Unknown / Non-Applicable   data analyst                        37000
# 3      $50 to $100 million (USD)   data analyst                        37000
# 4     $100 to $500 million (USD)   data analyst                        37000
# ...                          ...            ...                          ...
# 2523      $1 to $5 million (USD)  data engineer                        76000
# 2524     $5 to $10 million (USD)  data engineer                        76000
# 2525  $100 to $500 million (USD)  data engineer                        76000
# 2526    Unknown / Non-Applicable  data engineer                        76000
# 2527    $25 to $50 million (USD)  data engineer                        76000
#
#       Salary_Estimate_Upper_Bound  \
# 0                           66000
# 1                           66000
# 2                           66000
# 3                           66000
# 4                           66000
# ...                           ...
# 2523                       128000
# 2524                       128000
# 2525                       128000
# 2526                       128000
# 2527                       128000
#
#                                   clean_job_description  \
# 0     are you eager to roll up your sleeves and harn...
# 1     overview provides analytical and technical sup...
# 2     we re looking for a senior data analyst who ha...
# 3     requisition numberrr remote yes we collaborate...
# 4     about fanduel group fanduel group is a world c...
# ...                                                 ...
# 2523  the expertise you have proven expertise in dev...
# 2524  lockheed martin is seeking a circuit and fpga ...
# 2525  posting title principal data engineer contract...
# 2526  your opportunity charles schwab co inc is curr...
# 2527  cloud engineer westlake tx months description ...
#
#                              lemmatized_job_description  \
# 0     eager roll sleeve harness data drive policy ch...
# 1     overview provides analytical technical support...
# 2     looking senior data analyst love mentorship da...
# 3     requisition numberrr remote yes collaborate cr...
# 4     fanduel group fanduel group world class team b...
# ...                                                 ...
# 2523  expertise proven expertise developing applicat...
# 2524  lockheed martin seeking circuit fpga design el...
# 2525  posting title principal data engineer contract...
# 2526  opportunity charles schwab co inc currently se...
# 2527  cloud engineer westlake tx month description c...
#
#                                         clean_job_title
# 0     data analyst center on immigration and justice...
# 1                                  quality data analyst
# 2     senior data analyst insights analytics team cu...
# 3                                          data analyst
# 4                                reporting data analyst
# ...                                                 ...
# 2523                                     cloud engineer
# 2524                                electrical engineer
# 2525                               sr big data engineer
# 2526                       senior big data etl engineer
# 2527                                     cloud engineer
#
# [8656 rows x 17 columns]

# %%
df.loc[df.job_family == "data analyst"].to_csv("./data/data_analyst_job_postings_local.csv", index=False, sep="|")
df.loc[df.job_family == "data engineer"].to_csv("./data/data_engineer_job_postings_local.csv", index=False, sep="|")
df.loc[df.job_family == "data scientist"].to_csv("./data/data_scientist_job_postings_local.csv", index=False, sep="|")

# %%
df_out = df.reset_index()
df_out.drop(columns = df_out.columns[0],inplace=True)
df_out.index.names = ['job_id']
df_out.to_csv("./data/data_job_postings_clean.csv", sep='|', index=False)
